# %% [markdown]
# # Task-3: Exploratory Data Analysis - Retail
# ## Submitted by: Jannatul Ferdousi
#
# Here I will try to find out the weak areas in the given dataset to make more profit using Python

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
superstore= pd.read_csv("SampleSuperstore.csv")
superstore
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 13 columns]

# %% [markdown]
# ### Checking the data type

# %%
superstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
superstore.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# ### Checking NULL values

# %%
superstore.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# ### There is no NULL values in any cell

# %%
superstore.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
correlation=superstore.corr(method='kendall')
correlation
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.001465  0.010015  0.037496 -0.003111
# Sales          -0.001465  1.000000  0.238978 -0.041826  0.452118
# Quantity        0.010015  0.238978  1.000000 -0.000698  0.171843
# Discount        0.037496 -0.041826 -0.000698  1.000000 -0.428205
# Profit         -0.003111  0.452118  0.171843 -0.428205  1.000000

# %%
sns.heatmap(correlation, xticklabels= correlation.columns, yticklabels= correlation.columns, annot= True,)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Pie Chart

# %%
plt.figure(figsize=(8,8))
superstore['Region'].value_counts().plot.pie(autopct='%1.2f%%')
# Out:
# <AxesSubplot:ylabel='Region'>

# %%
plt.figure(figsize=(8,8))
superstore['Ship Mode'].value_counts().plot.pie(autopct='%1.2f%%')
# Out:
# <AxesSubplot:ylabel='Ship Mode'>

# %%
for col in superstore.columns:
    if superstore[col].dtype=='object':
        print(f'Unique {col} number is {superstore[col].nunique()}')
        print("---------------------------------")
# Out:
# Unique Ship Mode number is 4
# ---------------------------------
# Unique Segment number is 3
# ---------------------------------
# Unique Country number is 1
# ---------------------------------
# Unique City number is 531
# ---------------------------------
# Unique State number is 49
# ---------------------------------
# Unique Region number is 4
# ---------------------------------
# Unique Category number is 3
# ---------------------------------
# Unique Sub-Category number is 17
# ---------------------------------

# %% [markdown]
# ## Pairplot of data considering Category and Region as hue

# %%
sns.pairplot(superstore, hue='Category')

# %%
sns.pairplot(superstore, hue='Region')

# %% [markdown]
# ## Data have been grouped according to their catagory to see the most sold product

# %%
cat_group= superstore.groupby("Category")
total_quantity_sold= cat_group["Quantity"].agg(np.sum).sort_values(ascending= False).reset_index()
total_quantity_sold
# Out:
#           Category  Quantity
# 0  Office Supplies     22906
# 1        Furniture      8028
# 2       Technology      6939

# %%
plt.figure(figsize=(8,8))
superstore['Category'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Category'>

# %% [markdown]
# ### From the output table and pie chart above, we can see that office supplies products have been in the top with total quantity of 22786 , which is 60.2% of the total product sold.

# %%
subcat_group= superstore.groupby("Sub-Category")
total_quantity_sold= subcat_group["Quantity"].agg(np.sum).sort_values(ascending= False).reset_index()
total_quantity_sold
# Out:
#    Sub-Category  Quantity
# 0       Binders      5974
# 1         Paper      5178
# 2   Furnishings      3563
# 3        Phones      3289
# 4       Storage      3158
# 5           Art      3000
# 6   Accessories      2976
# 7        Chairs      2356
# 8    Appliances      1729
# 9        Labels      1400
# 10       Tables      1241
# 11    Fasteners       914
# 12    Envelopes       906
# 13    Bookcases       868
# 14     Supplies       647
# 15     Machines       440
# 16      Copiers       234

# %%
sns.barplot(x='Category', y='Sales', hue='Region', data= superstore, )
# Out:
# <AxesSubplot:xlabel='Category', ylabel='Sales'>

# %%
sns.barplot(x='Category', y='Profit', hue='Region', data= superstore, )
# Out:
# <AxesSubplot:xlabel='Category', ylabel='Profit'>

# %%
plt.figure(figsize=(9,6))
sns.barplot(x='Category', y='Profit', hue='Ship Mode', data= superstore, )
# Out:
# <AxesSubplot:xlabel='Category', ylabel='Profit'>

# %%
plt.figure(figsize=(9,6))
sns.barplot(x='Category', y='Sales', hue='Ship Mode', data= superstore, )
# Out:
# <AxesSubplot:xlabel='Category', ylabel='Sales'>

# %%
data=sns.barplot(x='Region', y='Sales', data= superstore,)
for item in data.get_xticklabels():
    item.set_rotation(90)

# %%
data=sns.barplot(x='Region', y='Profit', data= superstore,)
for item in data.get_xticklabels():
    item.set_rotation(90)

# %% [markdown]
# #### From four barchart shown above, it seems that technology products dominates in Sales, profits according to Ship_mode and Region.
#
# #### Lets sub-categorize Technology and see which subcategory dominates others in Sales, Profits according to Region, Ship_mode

# %%
tech_data= superstore[superstore['Category']=='Technology']
plt.figure(figsize=(9,6))
sns.barplot(x='Sub-Category', y='Sales',  data= tech_data, )
# Out:
# <AxesSubplot:xlabel='Sub-Category', ylabel='Sales'>

# %%
plt.figure(figsize=(9,6))
sns.barplot(x='Sub-Category', y='Profit', data= tech_data,palette='magma' )
# Out:
# <AxesSubplot:xlabel='Sub-Category', ylabel='Profit'>

# %%
plt.figure(figsize=(9,6))
plt.title("Sales of Technology's sub-categories according to Ship_mode")
sns.barplot(x='Sub-Category', y='Sales', hue='Ship Mode', data= tech_data, )
# Out:
# <AxesSubplot:title={'center':"Sales of Technology's sub-categories according to Ship_mode"}, xlabel='Sub-Category', ylabel='Sales'>

# %%
plt.figure(figsize=(9,6))
plt.title("Profit of Technology's sub-categories according to Ship_mode")
sns.barplot(x='Sub-Category', y='Profit', hue='Ship Mode', data= tech_data, )
# Out:
# <AxesSubplot:title={'center':"Profit of Technology's sub-categories according to Ship_mode"}, xlabel='Sub-Category', ylabel='Profit'>

# %%
plt.figure(figsize=(9,6))
plt.title("Sales of Technology's sub-categories according to Region")
sns.barplot(x='Sub-Category', y='Sales', hue='Region', data= tech_data, )
# Out:
# <AxesSubplot:title={'center':"Sales of Technology's sub-categories according to Region"}, xlabel='Sub-Category', ylabel='Sales'>

# %%
plt.figure(figsize=(9,6))
plt.title("Profit of Technology's sub-categories according to Region")
sns.barplot(x='Sub-Category', y='Profit', hue='Region', data= tech_data, )
# Out:
# <AxesSubplot:title={'center':"Profit of Technology's sub-categories according to Region"}, xlabel='Sub-Category', ylabel='Profit'>

# %% [markdown]
# ##### Grouping dataset according to Cities to see which ity makes highest and lowest total Sales and profits

# %%
city_group= superstore.groupby("City")
top_sales_among_cities= city_group["Sales"].agg(np.sum).sort_values(ascending= False).reset_index()
top_sales_among_cities
# Out:
#               City       Sales
# 0    New York City  256368.161
# 1      Los Angeles  175851.341
# 2          Seattle  119540.742
# 3    San Francisco  112669.092
# 4     Philadelphia  109077.013
# ..             ...         ...
# 526   Ormond Beach       2.808
# 527      Pensacola       2.214
# 528        Jupiter       2.064
# 529         Elyria       1.824
# 530        Abilene       1.392
#
# [531 rows x 2 columns]

# %%
sales_bar=sns.barplot(x='City', y='Sales', data=top_sales_among_cities.head(15))
for item in sales_bar.get_xticklabels():
    item.set_rotation(90)

# %%
top_sales_among_cities= city_group["Profit"].agg(np.sum).sort_values(ascending= False).reset_index()
top_sales_among_cities
# Out:
#               City      Profit
# 0    New York City  62036.9837
# 1      Los Angeles  30440.7579
# 2          Seattle  29156.0967
# 3    San Francisco  17507.3854
# 4          Detroit  13181.7908
# ..             ...         ...
# 526        Chicago  -6654.5688
# 527      Lancaster  -7239.0684
# 528    San Antonio  -7299.0502
# 529        Houston -10153.5485
# 530   Philadelphia -13837.7674
#
# [531 rows x 2 columns]

# %%
profit_bar=sns.barplot(x='City', y='Profit', data=top_sales_among_cities.head(15))
for item in profit_bar.get_xticklabels():
    item.set_rotation(90)

# %%
profit_bar_tail=sns.barplot(x='City', y='Profit', data=top_sales_among_cities.sort_values(by='Profit',ascending=True).head(15))
for item in profit_bar_tail.get_xticklabels():
    item.set_rotation(90)

# %%
average_sale=city_group['Sales'].agg(np.mean).sort_values(ascending=False).reset_index()
average_profit=city_group['Profit'].agg(np.mean).sort_values(ascending=False).reset_index()
average_discount=city_group['Discount'].agg(np.mean).sort_values(ascending=False).reset_index()
print(f'Average Sale:   ')
print('-----------------------')
print(average_sale.head())
print(f'Average Profit:  ')
print('-----------------------')
print(average_profit.head())
print(f'Average Discount:  ')
print('-----------------------')
print(average_discount.head())
# Out:
# Average Sale:
# -----------------------
#            City        Sales
# 0     Jamestown  2354.395000
# 1      Cheyenne  1603.136000
# 2    Bellingham  1263.413333
# 3  Independence  1208.685000
# 4       Burbank  1082.386000
# Average Profit:
# -----------------------
#            City      Profit
# 0     Jamestown  642.885750
# 1  Independence  487.831500
# 2     Lafayette  323.173794
# 3   Minneapolis  296.721070
# 4      Appleton  277.383150
# Average Discount:
# -----------------------
#             City  Discount
# 0      Deer Park       0.8
# 1        Abilene       0.8
# 2  Missouri City       0.8
# 3     Romeoville       0.8
# 4      Littleton       0.7

# %%
high_sale_and_profit= pd.merge(high_sales,high_profit, on=['City'], how='inner')
high_sale_and_profit
# Out:
#                City        Sales      Profit
# 0         Jamestown  2354.395000  642.885750
# 1          Cheyenne  1603.136000  100.196000
# 2        Bellingham  1263.413333  203.530267
# 3      Independence  1208.685000  487.831500
# 4           Burbank  1082.386000  254.844600
# 5           Beverly   861.063333  218.306467
# 6          Appleton   835.655000  277.383150
# 7         Lafayette   807.619355  323.173794
# 8          Torrance   783.067000  136.287750
# 9              Lehi   758.363000  225.831300
# 10      Minneapolis   733.501739  296.721070
# 11       Morristown   719.014286  262.603871
# 12     Saint Peters   697.160000  146.403600
# 13           Norman   675.665000  134.764350
# 14     Harrisonburg   626.958571  127.074843
# 15  North Las Vegas   612.562625  140.480619

# %%
high_sales= average_sale[average_sale['Sales']> 600]
low_sales= average_sale[average_sale['Sales']<= 50 ]


high_profit= average_profit[average_profit['Profit']> 100]
low_profit= average_profit[average_profit['Profit']<= 0]


high_discount= average_discount[average_discount['Discount']>= 0.6]
low_discount= average_discount[average_discount['Discount']< 0.6]

# %%
high_sale_low_profit= pd.merge(high_sales,low_profit, on=['City'], how='inner')
high_sale_low_profit
# Out:
#          City       Sales      Profit
# 0  Burlington  866.723280 -144.915088
# 1  Round Rock  693.436114 -169.061614
# 2  Richardson  644.232000  -12.244650

# %%
high_sale_low_discount= pd.merge(high_sales,low_discount, on=['City'], how='inner')
high_sale_low_discount
# Out:
#                City        Sales  Discount
# 0         Jamestown  2354.395000  0.000000
# 1          Cheyenne  1603.136000  0.200000
# 2        Bellingham  1263.413333  0.066667
# 3      Independence  1208.685000  0.000000
# 4           Burbank  1082.386000  0.066667
# 5           Buffalo   906.349600  0.060000
# 6        Burlington   866.723280  0.136000
# 7           Beverly   861.063333  0.000000
# 8            Sparks   853.986667  0.066667
# 9          Appleton   835.655000  0.000000
# 10        Lafayette   807.619355  0.000000
# 11         Torrance   783.067000  0.150000
# 12      Noblesville   772.795000  0.000000
# 13             Lehi   758.363000  0.100000
# 14        Kissimmee   751.984000  0.200000
# 15      Minneapolis   733.501739  0.000000
# 16       Morristown   719.014286  0.000000
# 17     Saint Peters   697.160000  0.000000
# 18       Round Rock   693.436114  0.274286
# 19      San Gabriel   687.003333  0.066667
# 20           Norman   675.665000  0.000000
# 21       Richardson   644.232000  0.400000
# 22     Harrisonburg   626.958571  0.000000
# 23  North Las Vegas   612.562625  0.037500

# %%
low_sale_and_profit= pd.merge(low_sales,low_profit, on=['City'], how='inner')
low_sale_and_profit
# Out:
#               City      Sales     Profit
# 0        Frankfort  48.816000 -13.028000
# 1          Mcallen  45.616632  -8.624826
# 2      Bolingbrook  36.384667  -0.776833
# 3            Mason  31.421333  -1.411733
# 4           Frisco  28.752000  -9.400800
# 5   Corpus Christi  27.568000  -5.466300
# 6       San Marcos  27.111000  -4.835325
# 7      Tinley Park  22.288000  -8.915200
# 8       Boca Raton  21.002667  -7.548533
# 9          Hickory  20.382000  -0.547800
# 10         Garland  16.926000  -8.093250
# 11        Mesquite  10.429600 -17.524000
# 12         Altoona  10.225500  -0.591750
# 13  Cuyahoga Falls   9.698000  -4.191733
# 14      Romeoville   8.952000 -14.770800
# 15       Deer Park   6.924000 -10.386000
# 16   Missouri City   6.370000  -9.555000
# 17    Ormond Beach   2.808000  -1.965600
# 18       Pensacola   2.214000  -1.476000
# 19          Elyria   1.824000  -1.398400
# 20         Abilene   1.392000  -3.758400

# %%
high_profit_low_discount= pd.merge(high_profit,low_discount, on=['City'], how='inner')
high_profit_low_discount
# Out:
#                 City      Profit  Discount
# 0          Jamestown  642.885750  0.000000
# 1       Independence  487.831500  0.000000
# 2          Lafayette  323.173794  0.000000
# 3        Minneapolis  296.721070  0.000000
# 4           Appleton  277.383150  0.000000
# 5         Morristown  262.603871  0.000000
# 6            Burbank  254.844600  0.066667
# 7               Lehi  225.831300  0.100000
# 8            Beverly  218.306467  0.000000
# 9            Warwick  212.759120  0.000000
# 10        Bellingham  203.530267  0.066667
# 11       Great Falls  197.838388  0.050000
# 12            Mobile  197.802655  0.000000
# 13           Midland  191.140233  0.008333
# 14           Yonkers  184.517047  0.066667
# 15           Atlanta  179.324690  0.000000
# 16        Providence  177.601835  0.009677
# 17           Dubuque  159.224800  0.000000
# 18        Sacramento  159.206608  0.123077
# 19       Saint Cloud  156.538000  0.000000
# 20          Missoula  152.495000  0.200000
# 21  Huntington Beach  146.673200  0.033333
# 22      Saint Peters  146.403600  0.000000
# 23   North Las Vegas  140.480619  0.037500
# 24          Torrance  136.287750  0.150000
# 25           Roswell  134.857517  0.000000
# 26            Norman  134.764350  0.000000
# 27        Twin Falls  133.082450  0.100000
# 28      Harrisonburg  127.074843  0.000000
# 29    Virginia Beach  126.555231  0.000000
# 30            Edmond  121.551950  0.000000
# 31      Indianapolis  119.202339  0.000000
# 32         Greenwood  117.933050  0.000000
# 33      Broken Arrow  115.104520  0.000000
# 34           Detroit  114.624268  0.006957
# 35           Kenosha  114.230311  0.000000
# 36           Madison  112.365520  0.000000
# 37          Muskogee  110.649150  0.000000
# 38         Vacaville  110.052800  0.000000
# 39        Washington  105.958930  0.000000
# 40          Florence  103.284100  0.000000
# 41          Evanston  102.970950  0.225000
# 42          Cheyenne  100.196000  0.200000

# %% [markdown]
# #### Grouping dataset according to Sub_categories to see which ity makes highest and lowest total Sales and profits

# %%
low_sale_high_discount= pd.merge(low_sales,high_discount, on=['City'], how='inner')
low_sale_high_discount
# Out:
#             City   Sales  Discount
# 0    Tinley Park  22.288       0.6
# 1     Romeoville   8.952       0.8
# 2      Deer Park   6.924       0.8
# 3  Missouri City   6.370       0.8
# 4   Ormond Beach   2.808       0.7
# 5      Pensacola   2.214       0.7
# 6         Elyria   1.824       0.7
# 7        Abilene   1.392       0.8

# %%
sales_bar=sns.barplot(x='Sub-Category', y='Sales', data=top_sales_among_sub_cat)
for item in sales_bar.get_xticklabels():
    item.set_rotation(90)

# %%
subcat_group= superstore.groupby("Sub-Category")
top_sales_among_sub_cat= subcat_group["Sales"].agg(np.sum).sort_values(ascending= False).reset_index()
top_sales_among_sub_cat
# Out:
#    Sub-Category        Sales
# 0        Phones  330007.0540
# 1        Chairs  328449.1030
# 2       Storage  223843.6080
# 3        Tables  206965.5320
# 4       Binders  203412.7330
# 5      Machines  189238.6310
# 6   Accessories  167380.3180
# 7       Copiers  149528.0300
# 8     Bookcases  114879.9963
# 9    Appliances  107532.1610
# 10  Furnishings   91705.1640
# 11        Paper   78479.2060
# 12     Supplies   46673.5380
# 13          Art   27118.7920
# 14    Envelopes   16476.4020
# 15       Labels   12486.3120
# 16    Fasteners    3024.2800

# %%
top_sales_among_sub_cat= subcat_group["Profit"].agg(np.sum).sort_values(ascending= False).reset_index()
top_sales_among_sub_cat
# Out:
#    Sub-Category      Profit
# 0       Copiers  55617.8249
# 1        Phones  44515.7306
# 2   Accessories  41936.6357
# 3         Paper  34053.5693
# 4       Binders  30221.7633
# 5        Chairs  26590.1663
# 6       Storage  21278.8264
# 7    Appliances  18138.0054
# 8   Furnishings  13059.1436
# 9     Envelopes   6964.1767
# 10          Art   6527.7870
# 11       Labels   5546.2540
# 12     Machines   3384.7569
# 13    Fasteners    949.5182
# 14     Supplies  -1189.0995
# 15    Bookcases  -3472.5560
# 16       Tables -17725.4811

# %%
top_discount_among_sub_cat= subcat_group["Discount"].agg(np.mean).sort_values(ascending= False).reset_index()
top_discount_among_sub_cat
# Out:
#    Sub-Category  Discount
# 0       Binders  0.372292
# 1      Machines  0.306087
# 2        Tables  0.261285
# 3     Bookcases  0.211140
# 4        Chairs  0.170178
# 5    Appliances  0.166524
# 6       Copiers  0.161765
# 7        Phones  0.154556
# 8   Furnishings  0.138349
# 9     Fasteners  0.082028
# 10    Envelopes  0.080315
# 11  Accessories  0.078452
# 12     Supplies  0.076842
# 13        Paper  0.074891
# 14          Art  0.074874
# 15      Storage  0.074704
# 16       Labels  0.068681

# %%
profit_bar=sns.barplot(x='Sub-Category', y='Profit', data=top_sales_among_sub_cat)
for item in profit_bar.get_xticklabels():
    item.set_rotation(90)

# %%
discount_bar=sns.barplot(x='Sub-Category', y='Discount', data=top_discount_among_sub_cat)
for item in discount_bar.get_xticklabels():
    item.set_rotation(90)

# %%
sub_average_sale=subcat_group['Sales'].agg(np.mean).sort_values(ascending=False).reset_index()
sub_average_profit=subcat_group['Profit'].agg(np.mean).sort_values(ascending=False).reset_index()
sub_average_discount=subcat_group['Discount'].agg(np.mean).sort_values(ascending=False).reset_index()
print('=== On the basis of Sub-Category ===')
print(f'Average Sale :   ')
print('-----------------------------')
print(sub_average_sale)
print(f'Average Profit:  ')
print('-----------------------------')
print(sub_average_profit)
print(f'Average Discount:  ')
print('-----------------------------')
print(sub_average_discount)
# Out:
# === On the basis of Sub-Category ===
# Average Sale :
# -----------------------------
#    Sub-Category        Sales
# 0       Copiers  2198.941618
# 1      Machines  1645.553313
# 2        Tables   648.794771
# 3        Chairs   532.332420
# 4     Bookcases   503.859633
# 5        Phones   371.211534
# 6       Storage   264.590553
# 7      Supplies   245.650200
# 8    Appliances   230.755710
# 9   Accessories   215.974604
# 10      Binders   133.560560
# 11  Furnishings    95.825668
# 12    Envelopes    64.867724
# 13        Paper    57.284092
# 14       Labels    34.303055
# 15          Art    34.068834
# 16    Fasteners    13.936774
# Average Profit:
# -----------------------------
#    Sub-Category      Profit
# 0       Copiers  817.909190
# 1   Accessories   54.111788
# 2        Phones   50.073938
# 3        Chairs   43.095894
# 4    Appliances   38.922758
# 5      Machines   29.432669
# 6     Envelopes   27.418019
# 7       Storage   25.152277
# 8         Paper   24.856620
# 9       Binders   19.843574
# 10       Labels   15.236962
# 11  Furnishings   13.645918
# 12          Art    8.200737
# 13    Fasteners    4.375660
# 14     Supplies   -6.258418
# 15    Bookcases  -15.230509
# 16       Tables  -55.565771
# Average Discount:
# -----------------------------
#    Sub-Category  Discount
# 0       Binders  0.372292
# 1      Machines  0.306087
# 2        Tables  0.261285
# 3     Bookcases  0.211140
# 4        Chairs  0.170178
# 5    Appliances  0.166524
# 6       Copiers  0.161765
# 7        Phones  0.154556
# 8   Furnishings  0.138349
# 9     Fasteners  0.082028
# 10    Envelopes  0.080315
# 11  Accessories  0.078452
# 12     Supplies  0.076842
# 13        Paper  0.074891
# 14          Art  0.074874
# 15      Storage  0.074704
# 16       Labels  0.068681

# %%
plt.figure(figsize=(7,7))
data=sns.barplot(x='Sub-Category', y='Sales', data= superstore,)
for item in data.get_xticklabels():
    item.set_rotation(90)

# %%
plt.figure(figsize=(7,7))
data=sns.barplot(x='Sub-Category', y='Profit', data= superstore,)
for item in data.get_xticklabels():
    item.set_rotation(90)

# %%
sub_high_sales= sub_average_sale[average_sale['Sales']> 100]
sub_low_sales= sub_average_sale[average_sale['Sales']<= 50 ]


sub_high_profit= sub_average_profit[average_profit['Profit']> 20]
sub_low_profit= sub_average_profit[average_profit['Profit']<= 0]


sub_high_discount= sub_average_discount[average_discount['Discount']>= 0.6]
sub_low_discount= sub_average_discount[average_discount['Discount']< 0.6]
# Out:
# <ipython-input-70-336bcd1f907a>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sub_high_sales= sub_average_sale[average_sale['Sales']> 100]
# <ipython-input-70-336bcd1f907a>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sub_low_sales= sub_average_sale[average_sale['Sales']<= 50 ]
# <ipython-input-70-336bcd1f907a>:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sub_high_profit= sub_average_profit[average_profit['Profit']> 20]
# <ipython-input-70-336bcd1f907a>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sub_low_profit= sub_average_profit[average_profit['Profit']<= 0]
# <ipython-input-70-336bcd1f907a>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sub_high_discount= sub_average_discount[average_discount['Discount']>= 0.6]
# <ipython-input-70-336bcd1f907a>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sub_low_discount= sub_average_discount[average_discount['Discount']< 0.6]

# %%
sub_high_sale_high_profit= pd.merge(sub_high_sales,sub_high_profit, on=['Sub-Category'], how='inner')
sub_high_sale_high_profit
# Out:
#    Sub-Category        Sales      Profit
# 0       Copiers  2198.941618  817.909190
# 1      Machines  1645.553313   29.432669
# 2        Tables   648.794771  -55.565771
# 3        Chairs   532.332420   43.095894
# 4     Bookcases   503.859633  -15.230509
# 5        Phones   371.211534   50.073938
# 6       Storage   264.590553   25.152277
# 7      Supplies   245.650200   -6.258418
# 8    Appliances   230.755710   38.922758
# 9   Accessories   215.974604   54.111788
# 10      Binders   133.560560   19.843574
# 11  Furnishings    95.825668   13.645918
# 12    Envelopes    64.867724   27.418019
# 13        Paper    57.284092   24.856620
# 14       Labels    34.303055   15.236962
# 15          Art    34.068834    8.200737
# 16    Fasteners    13.936774    4.375660

# %%
sub_high_sale_low_profit= pd.merge(sub_high_sales,sub_low_profit, on=['Sub-Category'], how='inner')
sub_high_sale_low_profit
# Out:
# Empty DataFrame
# Columns: [Sub-Category, Sales, Profit]
# Index: []

# %%
sub_high_sale_low_discount= pd.merge(sub_high_sales,sub_low_discount, on=['Sub-Category'], how='inner')
sub_high_sale_low_discount
# Out:
#   Sub-Category       Sales  Discount
# 0      Storage  264.590553  0.074704
# 1        Paper   57.284092  0.074891
# 2       Labels   34.303055  0.068681
# 3          Art   34.068834  0.074874

# %%
sub_high_profit_low_discount= pd.merge(sub_high_profit,sub_low_discount, on=['Sub-Category'], how='inner')
sub_high_profit_low_discount
# Out:
#   Sub-Category     Profit  Discount
# 0      Storage  25.152277  0.074704
# 1        Paper  24.856620  0.074891
# 2       Labels  15.236962  0.068681
# 3          Art   8.200737  0.074874

# %%
plt.figure(figsize=(10,10))
line=sns.lineplot(x='Sub-Category', y='Profit', hue='Discount', data= superstore)
for item in line.get_xticklabels():
    item.set_rotation(90)

# %%
plt.figure(figsize=(10,9))
sns.lineplot(x='Sales', y='Profit', hue='Discount', data= superstore)
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Profit'>

# %% [markdown]
# # From this visualization:
#
# 1. For Discount=0.0, the profit scale goes very high
# 2. For discount more than 0 or we may say 10,20 or 30% discount the profit is good but not the best.
# 3. For profit between 0.3 to 0.6 sales rate gets very high but it seems that the profit is not goos, sometimes it takes a lot loss when the sale is low.
# 4. For discount More than 0.6 the loss is very high , there has no profit and sale is also low

# %%
relplot=sns.relplot(x="Sub-Category", y="Profit", hue="Region", size="Sales",
            sizes=(40,500), alpha=.6, palette=['r','g','b','gray'],
            height=9, aspect=1, data=superstore)
leg = relplot._legend
leg.set_bbox_to_anchor([1.1,1]) 
leg._loc = 1
for axes in relplot.axes.flat:
    _ = axes.set_xticklabels(axes.get_xticklabels(), rotation=90)
plt.tight_layout()
# Out:
# <ipython-input-76-8c207239f085>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   _ = axes.set_xticklabels(axes.get_xticklabels(), rotation=90)

# %% [markdown]
# #### As a summary we can say that, Office suppliy products have highest quantity of items sold, on the other hand technology is in the bottom. But In total sales and Profits technology related items surpasses every other category . Among technology category copeirs makes highest sales and profits. Phones and other accessories remain in stable position but Machines have least profits and it has high tendancy to have loss. If we look at Regions, South region dominates in sales whereas west dominates in profit scale.New work city have highest sales and profits.Philadelphia report highest total loss of about -13843.2106 though it was fifth position in sales.
